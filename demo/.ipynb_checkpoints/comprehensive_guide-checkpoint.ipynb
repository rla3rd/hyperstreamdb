# %% [markdown]
# # HyperStreamDB: Full Pipeline Presentation
#
# **Version:** 0.1.9 (Alpha)
# **Project:** HyperStreamDB - Serverless Index-Streaming Data Lake
#
# This masterclass takes you from zero to a production-grade RAG pipeline, demonstrating hardware acceleration, hybrid search, and serverless table management.

# %% [markdown]
# ## 1. Setup & Environment
#
# We initialize our environment and ensure all vector search dependencies are loaded.

# %%
import hyperstreamdb as hdb
import pyarrow as pa
import pandas as pd
import numpy as np
import os, shutil, requests, time, warnings
from datasets import load_dataset
from sentence_transformers import SentenceTransformer

warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

print("Environment ready.")
# Out:
# Environment ready.

# %% [markdown]
# ## 2. Hardware Acceleration
#
# HyperStreamDB can utilize Intel GPUs for massively parallel index construction. We check for available hardware here.

# %% [markdown]
# GPU support for Nvidia, Intel, Apple MPS, AMD(ROCm - untested)

# %%
import torch
device = "cpu"
if torch.cuda.is_available():
    device = "cuda:0"
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    device = "mps"

print(f"Using device: {device}")
ctx = hdb.Device(device)
# Out:
# Using device: mps

# %% [markdown]
# ## 3. Data Preparation (AG News)
#
# We load the AG News dataset and generate semantic embeddings using a 384-dimensional SBERT model.

# %%
print("Loading dataset...")
dataset = load_dataset("ag_news", split="test[:500]")
df = pd.DataFrame(dataset)
label_map = {0: "World", 1: "Sports", 2: "Business", 3: "Sci/Tech"}
df["category"] = df["label"].map(label_map)

print("Generating embeddings...")
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(df["text"].tolist())
df["embedding"] = [list(e) for e in embeddings]
print(f"Prepared {len(df)} records with {len(df['embedding'][0])}D vectors.")

df["id"] = range(len(df))
# Out:
# Loading dataset...
# Generating embeddings...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prepared 500 records with 384D vectors.

# %% [markdown]
# ## 4. Table Creation (Serverless Iceberg)
#
# HyperStreamDB tables are serverless and use standard Iceberg/Parquet formats with sidecar indices.

# %%
TABLE_URI = "file:///tmp/hdb_masterclass"
if os.path.exists("/tmp/hdb_masterclass"): shutil.rmtree("/tmp/hdb_masterclass")

schema = pa.schema([
    ('id', pa.int32()), 
    ('category', pa.string()),
    ('text', pa.string()),
    ('embedding', pa.list_(pa.float32(), 384))
])

table = hdb.Table.create(TABLE_URI, schema, device=ctx)
print(f"Table created at {TABLE_URI}")
# Out:
# Table created at file:///tmp/hdb_masterclassCommitted Manifest v1 (Schema Update)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)

# %% [markdown]
# ## 5. Ingestion & Indexing
#
# We write the data and building HNSW vector indices and Inverted scalar indices simultaneously.

# %%
table.add_index_columns(["embedding", "category", "text"])
table.write(df[["id", "category", "text", "embedding"]])
table.commit()
print("Data ingested and indexed successfully.")
# Out:
# Optimizing data layout: Shuffling rows by vector similarity (LanceDB-style)...
# Written data to /tmp/hdb_masterclass/seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.parquet (500 rows)
# Building indexes for batch of 500 rows
# Indexing Int32 column: id
# Indexing String column: text
# Indexing String column: category
#   Found 4 unique values
# Indexing Vector column: embedding (type=FixedSizeList(Field { data_type: Float32, nullable: true }, 384))
#   Found 500 unique values
# String Inverted Index written to /tmp/hdb_masterclass/seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.category.inv.parquet
# Building HNSW-IVF index (blocking): 500 vectors, 384 dims, use_pq=false
# Building HNSW-IVF index: 500 vectors, 4 clusters, 384 dims, M=16, use_pq=false
# String Inverted Index written to /tmp/hdb_masterclass/seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.text.inv.parquet
# Committed Manifest: _manifest/v2.json
#   - K-Means took: 4.09ms (5 iterations, 4 clusters)
#   - Grouping vectors took: 324.38µs
#   - Building HNSW graphs took: 7.93ms (4 clusters)
# HNSW-IVF index built in 12.36ms: 4 non-empty clusters
# Committed Manifest: _manifest/v3.json
# Data ingested and indexed successfully.
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab, generated index_files=[IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.embedding.cluster_2.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.parquet, found index_files=[IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.embedding.cluster_2.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v2 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.parquet

# %% [markdown]
# ## 6. Hybrid Search Performance
#
# We perform a semantic search combined with a scalar filter to find 'Space' news in the 'Sci/Tech' category.

# %%
query_vec = list(model.encode("Latest milestones in space exploration"))

results = (table.filter("category = 'Sci/Tech'")
                 .vector_search(query_vec, k=3)
                 .to_pandas())

print("Hybrid Search Results (Sci/Tech + Vector):")
display(results[["category", "text", "distance"]])
# Out:
# Hybrid Search Results (Sci/Tech + Vector):
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
# DEBUG: Total entries to prune: 1
# DEBUG: Entry seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.parquet: partitions={}, index_files=[IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.embedding.cluster_2.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Searching for index for column: category. Available index files: [IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.embedding.cluster_2.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
#    category  \
# 0  Sci/Tech
# 1  Sci/Tech
# 2  Sci/Tech
#
#                                                                                                                                                     text  \
# 0  The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers ...
# 1  Stunt pilots to snag a falling NASA craft NASA #39;s three-year effort to bring some genuine star dust back to Earth is set for a dramatic finale ...
# 2  Mars Rovers Relay Images Through Mars Express European Space Agency -- ESAs Mars Express has relayed pictures from one of NASA's Mars rovers for t...
#
#    distance
# 0  1.113737
# 1  1.254462
# 2  1.255060

# %% [markdown]
# ## 7. SQL & pgvector Interface
#
# HyperStreamDB supports standard SQL with pgvector-compatible operators for vector distance.

# %%
session = hdb.Session()
session.register("news", table)

query_vec_str = str(query_vec).replace(' ', '')
sql_df = session.sql(f"""
    SELECT category, text, 
           embedding <-> '{query_vec_str}'::vector AS dist
    FROM news
    WHERE category = 'Sci/Tech'
    ORDER BY dist ASC LIMIT 3
""")
display(sql_df.to_pandas())
# Out:
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
# DEBUG: Searching for index for column: category. Available index files: [IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.embedding.cluster_2.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
#    category  \
# 0  Sci/Tech
# 1  Sci/Tech
# 2  Sci/Tech
#
#                                                                                                                                                     text  \
# 0  The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers ...
# 1  Stunt pilots to snag a falling NASA craft NASA #39;s three-year effort to bring some genuine star dust back to Earth is set for a dramatic finale ...
# 2  Mars Rovers Relay Images Through Mars Express European Space Agency -- ESAs Mars Express has relayed pictures from one of NASA's Mars rovers for t...
#
#        dist
# 0  1.055338
# 1  1.120027
# 2  1.120294

# %% [markdown]
# ## 8. Vector Aggregations
#
# Calculate semantic centroids for entire categories directly in SQL.

# %%
agg_df = session.sql("""
    SELECT category, 
           vector_avg(embedding) AS centroid,
           COUNT(*) as count
    FROM news
    GROUP BY category
    order by count asc
""").to_pandas()
display(agg_df[["category", "count"]])
# Out:
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
#    category  count
# 0  Business    106
# 1     World    122
# 2  Sci/Tech    127
# 3    Sports    145

# %% [markdown]
# ## 9. Table Maintenance
#
# Keep the data lake healthy by compacting small files and vacuuming history.

# %%
print(f"Files before: {len(table.manifest().entries)}")
table.compact()
table.commit()
print(f"Files after: {len(table.manifest().entries)}")

table.vacuum(retention_versions=1)
print("Vacuum complete.")
# Out:
# Files before: 0
# Starting compaction with strategy: binpack
# Files after: 0
# Found candidate: seg_dd564b4a-531b-40fa-8ec0-b804d85c90ab.parquet (1194034 bytes)
# Plan: Identified 1 bins to compact.
# Executing with parallelism: 4
# Written data to /var/folders/96/k023nzcn1nzc1dklrz5_k1t80000gn/T/hyperstream_compact_99d89eb6-40e9-4c87-b12b-40c46cbfb9b8/compacted_20260404210904_99d89eb6-40e9-4c87-b12b-40c46cbfb9b8.parquet (500 rows)
# Compacted bin 1 -> compacted_20260404210904_99d89eb6-40e9-4c87-b12b-40c46cbfb9b8.parquet
# Committing Batch: +1 entries, -1 paths
# Committed Manifest: _manifest/v4.json
# Vacuum complete.
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 3 on disk at Path { raw: "_manifest/v3.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v3 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 4 on disk at Path { raw: "_manifest/v4.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v4 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 4 on disk at Path { raw: "_manifest/v4.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v4 (entries=0)

# %% [markdown]
# ## 10. Advanced Partitioning
#
# Scale to massive datasets using identity partitioning on the category field.

# %%
PART_URI = "file:///tmp/part_demo"
if os.path.exists("/tmp/part_demo"): shutil.rmtree("/tmp/part_demo")

partition_spec = {
    "fields": [{"name": "category", "transform": "identity", "source_id": 1, "field_id": 1000}]
}

part_table = hdb.Table.create_partitioned(PART_URI, schema, partition_spec)
part_table.write(df[:100])
part_table.commit()

print("Partitioned physical layout:")
for entry in part_table.manifest().entries:
    print(f" - {entry.file_path.split('/')[-2:]}")
# Out:
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617, generated index_files=[IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.parquet, found index_files=[IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_68772b63-80fd-4389-8c2a-121d24a17ae2, generated index_files=[IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_68772b63-80fd-4389-8c2a-121d24a17ae2.parquet, found index_files=[IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_68772b63-80fd-4389-8c2a-121d24a17ae2.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44, generated index_files=[IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.parquet, found index_files=[IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e29cba0a-c1a6-457d-aef2-3b37c8aadb44.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: to_manifest_entry: segment_id=seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945, generated index_files=[IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: to_manifest_entry: segment_id=seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe, generated index_files=[IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.parquet, found index_files=[IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_031e7974-edb1-4ae6-9ee2-0a2abbb1a945.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: Background indexing task: segment=seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.parquet, found index_files=[IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d0b038fb-6abf-4e6b-a1ea-b6f0ee856cbe.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6, generated index_files=[IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.parquet, found index_files=[IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ff16bd4d-7763-4de3-8dc5-18664d5f0ac6.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_e3008dae-895e-4d9c-8680-c803ee134468, generated index_files=[IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_e3008dae-895e-4d9c-8680-c803ee134468.parquet, found index_files=[IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e3008dae-895e-4d9c-8680-c803ee134468.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_85616f50-cf51-4420-8477-ff4cd4f77cd4, generated index_files=[IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: Background indexing task: segment=seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.parquet, found index_files=[IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_85616f50-cf51-4420-8477-ff4cd4f77cd4.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_64e80478-059e-4177-8ebd-fc49894e5c13, generated index_files=[IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_64e80478-059e-4177-8ebd-fc49894e5c13.parquet, found index_files=[IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_64e80478-059e-4177-8ebd-fc49894e5c13.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: to_manifest_entry: segment_id=seg_39b37bcd-f5aa-4d59-b324-a0f936b38077, generated index_files=[IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.parquet, found index_files=[IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d, generated index_files=[IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.parquet, found index_files=[IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f249cb52-626c-4b2c-9bbf-d348cc67da1d.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab, generated index_files=[IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.parquet, found index_files=[IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3b67afc5-53e9-47cc-85f6-3f3e6dac87ab.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 1 on disk at Path { raw: "_manifest/v1.json" }
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_eada14ed-e53c-4623-b435-702eb6f1a486, generated index_files=[IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_469b94dd-8d59-45f9-a848-1b99c59dbce2, generated index_files=[IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23, generated index_files=[IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.parquet, found index_files=[IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_469b94dd-8d59-45f9-a848-1b99c59dbce2.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_eada14ed-e53c-4623-b435-702eb6f1a486.parquet, found index_files=[IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_eada14ed-e53c-4623-b435-702eb6f1a486.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.parquet, found index_files=[IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Successfully loaded v2 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_3c2373f1-c507-4082-8a76-f7d5d7946b62, generated index_files=[IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.parquet, found index_files=[IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3c2373f1-c507-4082-8a76-f7d5d7946b62.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# DEBUG: to_manifest_entry: segment_id=seg_95b30ab2-6b8f-40ae-9989-b09be309d79d, generated index_files=[IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.parquet, found index_files=[IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_7b19a052-5161-4a8f-9144-f7901bfcc843, generated index_files=[IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_7b19a052-5161-4a8f-9144-f7901bfcc843.parquet, found index_files=[IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7b19a052-5161-4a8f-9144-f7901bfcc843.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# DEBUG: to_manifest_entry: segment_id=seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1, generated index_files=[IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081, generated index_files=[IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.parquet, found index_files=[IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Successfully loaded v1 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_de58e263-71ce-4bce-88c7-8d022d526858, generated index_files=[IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_de58e263-71ce-4bce-88c7-8d022d526858.parquet, found index_files=[IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_de58e263-71ce-4bce-88c7-8d022d526858.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.parquet, found index_files=[IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d, generated index_files=[IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.parquet, found index_files=[IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_4f592389-4612-489e-a41b-edf7d447125a, generated index_files=[IndexFile { file_path: "seg_4f592389-4612-489e-a41b-edf7d447125a.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_4f592389-4612-489e-a41b-edf7d447125a.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_4f592389-4612-489e-a41b-edf7d447125a.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_4f592389-4612-489e-a41b-edf7d447125a.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_952265a5-3a72-4209-b6ca-9f613d40c49c, generated index_files=[IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_e1fe8f5c-7825-4af1-8769-9a13f89b0849, generated index_files=[IndexFile { file_path: "seg_e1fe8f5c-7825-4af1-8769-9a13f89b0849.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e1fe8f5c-7825-4af1-8769-9a13f89b0849.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e1fe8f5c-7825-4af1-8769-9a13f89b0849.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_e1fe8f5c-7825-4af1-8769-9a13f89b0849.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f, generated index_files=[IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_86ddcef8-d159-4c11-bc45-d9c763b89a18, generated index_files=[IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# DEBUG: Background indexing task: segment=seg_952265a5-3a72-4209-b6ca-9f613d40c49c.parquet, found index_files=[IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_952265a5-3a72-4209-b6ca-9f613d40c49c.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.parquet, found index_files=[IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1a2d3f45-6f24-4d69-9ba6-1df7acfaa42f.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.parquet, found index_files=[IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_86ddcef8-d159-4c11-bc45-d9c763b89a18.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# DEBUG: ManifestManager::load_latest: Found version 2 on disk at Path { raw: "_manifest/v2.json" }
# ...
# Committed Manifest: _manifest/v62.json
# Committed Manifest: _manifest/v63.json
# Committed Manifest: _manifest/v64.json
# Committed Manifest: _manifest/v65.json
# Committed Manifest: _manifest/v66.json
# DEBUG: ManifestManager::load_latest: Found version 61 on disk at Path { raw: "_manifest/v61.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v61 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_95b30ab2-6b8f-40ae-9989-b09be309d79d.parquet
# DEBUG: ManifestManager::load_latest: Found version 62 on disk at Path { raw: "_manifest/v62.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v62 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 62 on disk at Path { raw: "_manifest/v62.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v62 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 62 on disk at Path { raw: "_manifest/v62.json" }
# Successfully attached 4 indexes to manifest for segment seg_aa9caf49-0435-4b66-82aa-8c80d4b63b0d.parquet
# DEBUG: ManifestManager::load_latest: Successfully loaded v62 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 63 on disk at Path { raw: "_manifest/v63.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v63 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_9dee3e60-5257-4323-bd3e-851a25f94beb.parquet
# DEBUG: ManifestManager::load_latest: Found version 64 on disk at Path { raw: "_manifest/v64.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v64 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_7be6f056-a93c-44dc-9ae8-652ae8525a46.parquet
# DEBUG: ManifestManager::load_latest: Found version 65 on disk at Path { raw: "_manifest/v65.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v65 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_39b37bcd-f5aa-4d59-b324-a0f936b38077.parquet
# DEBUG: ManifestManager::load_latest: Found version 66 on disk at Path { raw: "_manifest/v66.json" }
# DEBUG: ManifestManager::load_latest: Found version 66 on disk at Path { raw: "_manifest/v66.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v66 (entries=0)
# DEBUG: ManifestManager::load_latest: Successfully loaded v66 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_e1fe8f5c-7825-4af1-8769-9a13f89b0849.parquet
# DEBUG: ManifestManager::load_latest: Found version 67 on disk at Path { raw: "_manifest/v67.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v67 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_8754d188-c8a0-4033-9c85-a9efb430a6b8.parquet
# DEBUG: ManifestManager::load_latest: Found version 68 on disk at Path { raw: "_manifest/v68.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v68 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_3e85e901-63b5-42f5-9de0-319db8e9004b.parquet
# DEBUG: ManifestManager::load_latest: Found version 69 on disk at Path { raw: "_manifest/v69.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v69 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 69 on disk at Path { raw: "_manifest/v69.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v69 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_04ad9883-2a76-49da-bca3-7e64ed296fa8.parquet
# DEBUG: ManifestManager::load_latest: Found version 70 on disk at Path { raw: "_manifest/v70.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v70 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 70 on disk at Path { raw: "_manifest/v70.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v70 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_952265a5-3a72-4209-b6ca-9f613d40c49c.parquet
# DEBUG: ManifestManager::load_latest: Found version 71 on disk at Path { raw: "_manifest/v71.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v71 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_deec73e1-dc76-4c16-acbe-96da09f11578.parquet
# DEBUG: ManifestManager::load_latest: Found version 72 on disk at Path { raw: "_manifest/v72.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v72 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_5d659aa6-409c-414d-bae8-926ee22e5f5a.parquet
# DEBUG: ManifestManager::load_latest: Found version 73 on disk at Path { raw: "_manifest/v73.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v73 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_0cc00ea0-eb9c-4b77-bf0e-96ec0182879b.parquet
# DEBUG: ManifestManager::load_latest: Found version 73 on disk at Path { raw: "_manifest/v73.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v73 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 74 on disk at Path { raw: "_manifest/v74.json" }
# DEBUG: ManifestManager::load_latest: Found version 74 on disk at Path { raw: "_manifest/v74.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v74 (entries=0)
# DEBUG: ManifestManager::load_latest: Successfully loaded v74 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_e02d0f70-2632-4e8f-9ad9-c7afd8eb7081.parquet
# DEBUG: ManifestManager::load_latest: Found version 75 on disk at Path { raw: "_manifest/v75.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v75 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_69f9e6ff-6a0e-4791-9f55-83082bf2f440.parquet
# DEBUG: ManifestManager::load_latest: Found version 75 on disk at Path { raw: "_manifest/v75.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v75 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 76 on disk at Path { raw: "_manifest/v76.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v76 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_be93ea0f-3a8a-47d1-9245-938671c35e18.parquet
# DEBUG: ManifestManager::load_latest: Found version 77 on disk at Path { raw: "_manifest/v77.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v77 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_7b222f65-8505-4d51-989b-cfedca80d719.parquet
# DEBUG: ManifestManager::load_latest: Found version 78 on disk at Path { raw: "_manifest/v78.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v78 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 78 on disk at Path { raw: "_manifest/v78.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v78 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_35aefa53-980c-46c8-8929-c21e7c4c0d6c.parquet
# DEBUG: ManifestManager::load_latest: Found version 79 on disk at Path { raw: "_manifest/v79.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v79 (entries=0)
# Committed Manifest: _manifest/v67.json
# Committed Manifest: _manifest/v68.json
# Committed Manifest: _manifest/v69.json
# Committed Manifest: _manifest/v70.json
# Committed Manifest: _manifest/v71.json
# Committed Manifest: _manifest/v72.json
# Committed Manifest: _manifest/v73.json
# Committed Manifest: _manifest/v74.json
# Committed Manifest: _manifest/v75.json
# Committed Manifest: _manifest/v76.json
# Committed Manifest: _manifest/v77.json
# Committed Manifest: _manifest/v78.json
# Committed Manifest: _manifest/v79.json
# Committed Manifest: _manifest/v80.json
# Committed Manifest: _manifest/v81.json
# Committed Manifest: _manifest/v82.json
# Successfully attached 4 indexes to manifest for segment seg_e8115ecf-9e27-4595-a510-744981e404d1.parquet
# DEBUG: ManifestManager::load_latest: Found version 80 on disk at Path { raw: "_manifest/v80.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v80 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 80 on disk at Path { raw: "_manifest/v80.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v80 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_dd9bd59d-2214-45fd-9eac-8d37375b4914.parquet
# DEBUG: ManifestManager::load_latest: Found version 81 on disk at Path { raw: "_manifest/v81.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v81 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_e3008dae-895e-4d9c-8680-c803ee134468.parquet
# DEBUG: ManifestManager::load_latest: Found version 82 on disk at Path { raw: "_manifest/v82.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v82 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_677b6b45-e9d2-4678-95a4-52f010fc2642.parquet
# DEBUG: ManifestManager::load_latest: Found version 83 on disk at Path { raw: "_manifest/v83.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v83 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_be795f7e-0638-49c7-8f1e-761f3543989d.parquet
# DEBUG: ManifestManager::load_latest: Found version 83 on disk at Path { raw: "_manifest/v83.json" }
# DEBUG: ManifestManager::load_latest: Found version 83 on disk at Path { raw: "_manifest/v83.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v83 (entries=0)
# DEBUG: ManifestManager::load_latest: Successfully loaded v83 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 84 on disk at Path { raw: "_manifest/v84.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v84 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_fe9b04a7-6c18-4b65-abbb-203e69c5af73.parquet
# DEBUG: ManifestManager::load_latest: Found version 85 on disk at Path { raw: "_manifest/v85.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v85 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_6180a8c4-7c12-43f7-a795-39bd796a882b.parquet
# DEBUG: ManifestManager::load_latest: Found version 86 on disk at Path { raw: "_manifest/v86.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v86 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_d78edf06-17bb-4878-8fd4-e0f1133f3fda.parquet
# DEBUG: ManifestManager::load_latest: Found version 87 on disk at Path { raw: "_manifest/v87.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v87 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_340cc719-bffa-4fe4-b1da-96bd73d81538.parquet
# Committed Manifest: _manifest/v83.json
# Committed Manifest: _manifest/v84.json
# Committed Manifest: _manifest/v85.json
# Committed Manifest: _manifest/v86.json
# Committed Manifest: _manifest/v87.json
# Committed Manifest: _manifest/v88.json
# Committed Manifest: _manifest/v89.json
# Committed Manifest: _manifest/v90.json
# DEBUG: ManifestManager::load_latest: Found version 88 on disk at Path { raw: "_manifest/v88.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v88 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_4a2baeff-d2c5-4d9d-822d-66a938a57069.parquet
# DEBUG: ManifestManager::load_latest: Found version 89 on disk at Path { raw: "_manifest/v89.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v89 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_48f4cd2c-15eb-46e1-85f7-a7acb8e71f23.parquet
# DEBUG: ManifestManager::load_latest: Found version 90 on disk at Path { raw: "_manifest/v90.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v90 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_eceb824d-2037-4002-be98-d53c292469a5.parquet
# DEBUG: ManifestManager::load_latest: Found version 91 on disk at Path { raw: "_manifest/v91.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v91 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_85bcb0ce-7572-4696-8946-2e2f9dfa69fd.parquet
# DEBUG: ManifestManager::load_latest: Found version 92 on disk at Path { raw: "_manifest/v92.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v92 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_20d10b93-6efa-4bf9-829b-7b1f3ee381c0.parquet
# DEBUG: ManifestManager::load_latest: Found version 93 on disk at Path { raw: "_manifest/v93.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v93 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_67b40b32-7a01-4d98-b66c-601c2cff76a3.parquet
# DEBUG: ManifestManager::load_latest: Found version 93 on disk at Path { raw: "_manifest/v93.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v93 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 94 on disk at Path { raw: "_manifest/v94.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v94 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 94 on disk at Path { raw: "_manifest/v94.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v94 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_b3e8ce93-2142-422b-8fad-4f0773c072b6.parquet
# Committed Manifest: _manifest/v91.json
# Committed Manifest: _manifest/v92.json
# Committed Manifest: _manifest/v93.json
# Committed Manifest: _manifest/v94.json
# Committed Manifest: _manifest/v95.json
# Committed Manifest: _manifest/v96.json
# DEBUG: ManifestManager::load_latest: Found version 95 on disk at Path { raw: "_manifest/v95.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v95 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_5d8839c7-eca5-4e8e-95de-1fa246cb2425.parquet
# DEBUG: ManifestManager::load_latest: Found version 96 on disk at Path { raw: "_manifest/v96.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v96 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_467b1929-5143-4441-8c61-281e3a7afd65.parquet
# DEBUG: ManifestManager::load_latest: Found version 97 on disk at Path { raw: "_manifest/v97.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v97 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_9bb3955a-8864-4fee-85a2-3ba8964a2c16.parquet
# DEBUG: ManifestManager::load_latest: Found version 97 on disk at Path { raw: "_manifest/v97.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v97 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 98 on disk at Path { raw: "_manifest/v98.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v98 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_64e80478-059e-4177-8ebd-fc49894e5c13.parquet
# Committed Manifest: _manifest/v97.json
# Committed Manifest: _manifest/v98.json
# Committed Manifest: _manifest/v99.json
# DEBUG: ManifestManager::load_latest: Found version 99 on disk at Path { raw: "_manifest/v99.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v99 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_f8a70501-d89d-40af-a1e4-3fbde3ba749a.parquet
# DEBUG: ManifestManager::load_latest: Found version 99 on disk at Path { raw: "_manifest/v99.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v99 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 100 on disk at Path { raw: "_manifest/v100.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v100 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_6d4899fd-81bd-4ffa-be0a-104121f8dfa1.parquet
# Committed Manifest: _manifest/v100.json
# Committed Manifest: _manifest/v101.json
# Committed Manifest: _manifest/v102.json
# Partitioned physical layout:
# DEBUG: ManifestManager::load_latest: Found version 101 on disk at Path { raw: "_manifest/v101.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v101 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_6efbc46e-fa4d-4fef-8db0-d81a2c3f8617.parquet
# DEBUG: ManifestManager::load_latest: Found version 102 on disk at Path { raw: "_manifest/v102.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v102 (entries=0)

# %% [markdown]
# ## 11. End-to-End RAG Pipeline
#
# Using SQuAD validation data to build a knowledge-backed Q&A system.

# %%
print("Loading SQuAD contexts...")
squad = load_dataset("squad", split="validation[0:100]")
squad_df = pd.DataFrame(squad).drop_duplicates(subset=["context"])

squad_emb = model.encode(squad_df["context"].tolist(), show_progress_bar=True)
squad_df["embedding"] = [list(e) for e in squad_emb]

rag_table = hdb.Table("rag_db_presentation")
rag_table.add_index_columns(["embedding", "context"])
rag_table.write(squad_df[["context", "title", "embedding"]])
rag_table.commit()
print("RAG knowledge base initialized.")
# Out:
# Loading SQuAD contexts...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Written data to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing String column: context
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true }))
# Indexing Int64 column: __index_level_0__
#   Found 4 unique values
# Indexing String column: title
#   Found 1 unique values
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
# Building HNSW-IVF index: 4 vectors, 1 clusters, 384 dims, M=16, use_pq=false
#   [K-Means] Converged early at iteration 2
# String Inverted Index written to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.context.inv.parquet
#   - K-Means took: 192.63µs (5 iterations, 1 clusters)
#   - Grouping vectors took: 63.92µs
# String Inverted Index written to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.title.inv.parquet
#   - Building HNSW graphs took: 51.92µs (1 clusters)
# HNSW-IVF index built in 315.54µs: 1 non-empty clusters
# Written data to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing String column: context
# Indexing String column: title
#   Found 4 unique values
#   Found 1 unique values
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true, metadata: {"iceberg.id": "301"} }))
# Indexing Int64 column: __index_level_0__
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
# Building HNSW-IVF index: 4 vectors, 1 clusters, 384 dims, M=16, use_pq=false
#   [K-Means] Converged early at iteration 2
#   - K-Means took: 83.67µs (5 iterations, 1 clusters)
#   - Grouping vectors took: 28.88µs
#   - Building HNSW graphs took: 20.08µs (1 clusters)
# HNSW-IVF index built in 136.79µs: 1 non-empty clusters
# String Inverted Index written to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.title.inv.parquet
# String Inverted Index written to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.context.inv.parquet
# Written data to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_ffc57efc-6e76-4d5c-a999-8888e056639c.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing String column: context
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true, metadata: {"iceberg.id": "301"} }))
#   Found 4 unique values
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
# Indexing String column: title
# Building HNSW-IVF index: 4 vectors, 1 clusters, 384 dims, M=16, use_pq=false
#   Found 1 unique values
# Indexing Int64 column: __index_level_0__
#   [K-Means] Converged early at iteration 2
#   - K-Means took: 96.13µs (5 iterations, 1 clusters)
#   - Grouping vectors took: 53.50µs
#   - Building HNSW graphs took: 122.58µs (1 clusters)
# HNSW-IVF index built in 305.46µs: 1 non-empty clusters
# String Inverted Index written to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_ffc57efc-6e76-4d5c-a999-8888e056639c.context.inv.parquet
# String Inverted Index written to /Users/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_ffc57efc-6e76-4d5c-a999-8888e056639c.title.inv.parquet
# Committed Manifest: _manifest/v7.json
# Committed Manifest: _manifest/v8.json
# RAG knowledge base initialized.
# DEBUG: ManifestManager::load_latest: Found version 5 on disk at Path { raw: "_manifest/v5.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v5 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 5 on disk at Path { raw: "_manifest/v5.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v5 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 5 on disk at Path { raw: "_manifest/v5.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v5 (entries=0)
# DEBUG: to_manifest_entry: segment_id=seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e, generated index_files=[IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077, generated index_files=[IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 5 on disk at Path { raw: "_manifest/v5.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v5 (entries=0)
# DEBUG: ManifestManager::load_latest: Found version 6 on disk at Path { raw: "_manifest/v6.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v6 (entries=2)
# DEBUG: ManifestManager::load_latest: Found version 6 on disk at Path { raw: "_manifest/v6.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v6 (entries=2)
# DEBUG: ManifestManager::load_latest: Found version 6 on disk at Path { raw: "_manifest/v6.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v6 (entries=2)
# DEBUG: to_manifest_entry: segment_id=seg_ffc57efc-6e76-4d5c-a999-8888e056639c, generated index_files=[IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_ffc57efc-6e76-4d5c-a999-8888e056639c.parquet, found index_files=[IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: ManifestManager::load_latest: Found version 6 on disk at Path { raw: "_manifest/v6.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v6 (entries=2)
# DEBUG: ManifestManager::load_latest: Found version 7 on disk at Path { raw: "_manifest/v7.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v7 (entries=0)
# Successfully attached 4 indexes to manifest for segment seg_ffc57efc-6e76-4d5c-a999-8888e056639c.parquet

# %% [markdown]
# ## 12. Inference with Retrieval
#
# Connect retrieval to the LLM (requires GROQ_API_KEY).

# %%
def ask_hdb(question):
    # Convert question to an embedding (using your local model)
    q_emb = model.encode(question)
    
    # Perform a vector search on your table
    # This is where your table data gets pulled in!
    ctx_df = rag_table.to_pandas(vector_filter={
        "column": "embedding", 
        "query": q_emb, 
        "k": 3  # Get top 3 matching contexts
    })
    
    # Combine retrieved contexts into one string
    contexts = ctx_df["context"].tolist()
    prompt = f"Answer the question based ONLY on this context:\n\n" + "\n".join(contexts) + f"\n\nQuestion: {question}"
    
    # Use a supported Groq model
    model_name = "llama-3.3-70b-versatile"
    
    api_key = os.environ.get("GROQ_TOKEN")
    r = requests.post("https://api.groq.com/openai/v1/chat/completions", 
                      headers={"Authorization": f"Bearer {api_key}"},
                      json={"model": model_name, "messages": [{"role": "user", "content": prompt}]})
    
    res = r.json()
    if "choices" not in res:
        # This will show you the exact error from Groq (e.g., "model_not_found")
        print(f"Groq API Error: {res}")
        return "Error from API"
        
    return res["choices"][0]["message"]["content"]

# %%
question = "Where were the first modern Olympic games?"
print(f"Q: {question}\nA: {ask_hdb(question)}")
# Out:
# DEBUG: ManifestManager::load_latest: Found version 8 on disk at Path { raw: "_manifest/v8.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v8 (entries=0)
# DEBUG: Total entries to prune: 3
# DEBUG: Entry seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.parquet: partitions={}, index_files=[IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Entry seg_ffc57efc-6e76-4d5c-a999-8888e056639c.parquet: partitions={}, index_files=[IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Entry seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.parquet: partitions={}, index_files=[IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# Q: Where were the first modern Olympic games?
# A: The context provided does not mention the location of the first modern Olympic games. The information is about Super Bowl 50, its broadcast, commercial costs, halftime show, and viewership. It does not contain any details about the Olympic games.

# %%
question = "What city was superbowl 50 played at?"
print(f"Q: {question}\nA: {ask_hdb(question)}")
# Out:
# DEBUG: ManifestManager::load_latest: Found version 8 on disk at Path { raw: "_manifest/v8.json" }
# DEBUG: ManifestManager::load_latest: Successfully loaded v8 (entries=0)
# DEBUG: Total entries to prune: 3
# DEBUG: Entry seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.parquet: partitions={}, index_files=[IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2d2d539-d05e-4976-8bcb-3a9c38113a5e.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Entry seg_ffc57efc-6e76-4d5c-a999-8888e056639c.parquet: partitions={}, index_files=[IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_ffc57efc-6e76-4d5c-a999-8888e056639c.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Entry seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.parquet: partitions={}, index_files=[IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_7c134cc4-c2d1-48aa-8d11-5298ec6c7077.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# Q: What city was superbowl 50 played at?
# A: The game was played at Levi's Stadium in the San Francisco Bay Area at Santa Clara, California.
