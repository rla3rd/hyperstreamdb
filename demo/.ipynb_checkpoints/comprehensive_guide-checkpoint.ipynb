# %% [markdown]
# # HyperStreamDB: Full Pipeline Presentation
#
# **Version:** 0.2.5 (Alpha)
# **Project:** HyperStreamDB - Serverless Index-Streaming Data Lake
#
# This masterclass takes you from zero to a production-grade RAG pipeline, demonstrating hardware acceleration, hybrid search, and serverless table management.

# %%
import logging
import hyperstreamdb as hdb

# Silence debug noise, only show WARNING and ERROR
logging.basicConfig(level=logging.WARNING)
logger = logging.getLogger('hyperstreamdb')
logger.setLevel(logging.WARNING)
print("HyperStreamDB Logging Level set to WARNING")
# Out:
# HyperStreamDB Logging Level set to WARNING

# %% [markdown]
# ## 1. Setup & Environment
#
# We initialize our environment and ensure all vector search dependencies are loaded.

# %%
import hyperstreamdb as hdb
import pyarrow as pa
import pandas as pd
import numpy as np
import os, shutil, requests, time, warnings
from datasets import load_dataset
from sentence_transformers import SentenceTransformer

warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 150)

print("Environment ready.")
# Out:
# Environment ready.

# %% [markdown]
# ## 2. Hardware Acceleration
#
# HyperStreamDB can utilize Intel GPUs for massively parallel index construction. We check for available hardware here.

# %% [markdown]
# GPU support for Nvidia, Intel, Apple MPS, AMD(ROCm - untested)

# %%
import torch
device = "cpu"
if hdb.Device.is_available("cuda") or (hasattr(torch, "cuda") and torch.cuda.is_available()):
    device = "cuda:0"
elif hasattr(torch.backends, "mps") and torch.backends.mps.is_available():
    device = "mps"

print(f"Using device: {device}")
ctx = hdb.Device(device)
# Out:
# Using device: cuda:0

# %% [markdown]
# ## 3. Data Preparation (AG News)
#
# We load the AG News dataset and generate semantic embeddings using a 384-dimensional SBERT model.

# %%
print("Loading dataset...")
dataset = load_dataset("ag_news", split="test[:500]")
df = pd.DataFrame(dataset)
label_map = {0: "World", 1: "Sports", 2: "Business", 3: "Sci/Tech"}
df["category"] = df["label"].map(label_map)

print("Generating embeddings...")
model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model.encode(df["text"].tolist())
df["embedding"] = [list(e) for e in embeddings]
print(f"Prepared {len(df)} records with {len(df['embedding'][0])}D vectors.")

df["id"] = range(len(df))
# Out:
# Loading dataset...
# Generating embeddings...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prepared 500 records with 384D vectors.

# %% [markdown]
# ## 4. Table Creation (Serverless Iceberg)
#
# HyperStreamDB tables are serverless and use standard Iceberg/Parquet formats with sidecar indices.

# %%
TABLE_URI = "file:///tmp/hdb_masterclass"
if os.path.exists("/tmp/hdb_masterclass"): shutil.rmtree("/tmp/hdb_masterclass")

schema = pa.schema([
    ('id', pa.int32()), 
    ('category', pa.string()),
    ('text', pa.string()),
    ('embedding', pa.list_(pa.float32(), 384))
])

table = hdb.Table.create(TABLE_URI, schema, device=ctx)
print(f"Table created at {TABLE_URI}")
# Out:
# Table created at file:///tmp/hdb_masterclass

# %% [markdown]
# ## 5. Ingestion & Indexing
#
# We write the data and building HNSW vector indices and Inverted scalar indices simultaneously.

# %%
table.add_index_columns(["embedding", "category", "text"])
table.write(df[["id", "category", "text", "embedding"]])
table.commit()
print("Data ingested and indexed successfully.")
# Out:
# Optimizing data layout: Shuffling rows by vector similarity (LanceDB-style)...
# Written data to /tmp/hdb_masterclass/seg_1c86016c-eb3e-4947-9821-064346d1984d.parquet (500 rows)
# Building indexes for batch of 500 rows
# Indexing Int32 column: id
# Indexing String column: text
# Indexing Vector column: embedding (type=FixedSizeList(Field { data_type: Float32, nullable: true }, 384))
# Indexing String column: category
#   Found 4 unique values
# String Inverted Index written to /tmp/hdb_masterclass/seg_1c86016c-eb3e-4947-9821-064346d1984d.category.inv.parquet
#   Found 500 unique values
# String Inverted Index written to /tmp/hdb_masterclass/seg_1c86016c-eb3e-4947-9821-064346d1984d.text.inv.parquet
# Building HNSW-IVF index (blocking): 500 vectors, 384 dims, use_pq=false
# Data ingested and indexed successfully.
# DEBUG: to_manifest_entry: segment_id=seg_1c86016c-eb3e-4947-9821-064346d1984d, generated index_files=[IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.embedding.cluster_1.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_1c86016c-eb3e-4947-9821-064346d1984d.parquet, found index_files=[IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1c86016c-eb3e-4947-9821-064346d1984d.embedding.cluster_1.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# Successfully attached 4 indexes to manifest for segment seg_1c86016c-eb3e-4947-9821-064346d1984d.parquet

# %% [markdown]
# ## 6. Hybrid Search Performance
#
# We perform a semantic search combined with a scalar filter to find 'Space' news in the 'Sci/Tech' category.

# %%
query_vec = list(model.encode("Latest milestones in space exploration"))

results = (table.filter("category = 'Sci/Tech'")
                 .vector_search(query_vec, k=3)
                 .to_pandas())

print("Hybrid Search Results (Sci/Tech + Vector):")
display(results[["category", "text", "distance"]])
# Out:
# Hybrid Search Results (Sci/Tech + Vector):
#    category  \
# 0  Sci/Tech
# 1  Sci/Tech
# 2  Sci/Tech
#
#                                                                                                                                                     text  \
# 0  The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers ...
# 1  Stunt pilots to snag a falling NASA craft NASA #39;s three-year effort to bring some genuine star dust back to Earth is set for a dramatic finale ...
# 2  Mars Rovers Relay Images Through Mars Express European Space Agency -- ESAs Mars Express has relayed pictures from one of NASA's Mars rovers for t...
#
#    distance
# 0  1.113737
# 1  1.254462
# 2  1.255060

# %% [markdown]
# ## 7. SQL & pgvector Interface
#
# HyperStreamDB supports standard SQL with pgvector-compatible operators for vector distance.

# %%
session = hdb.Session()
session.register("news", table)

query_vec_str = str([float(x) for x in query_vec]).replace(' ', '')
sql_df = session.sql(f"""
    SELECT category, text, 
           embedding <-> '{query_vec_str}'::vector AS dist
    FROM news
    WHERE category = 'Sci/Tech'
    ORDER BY dist ASC LIMIT 3
""")
display(sql_df.to_pandas())
# Out:
#    category  \
# 0  Sci/Tech
# 1  Sci/Tech
# 2  Sci/Tech
#
#                                                                                                                                                     text  \
# 0  The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers ...
# 1  Stunt pilots to snag a falling NASA craft NASA #39;s three-year effort to bring some genuine star dust back to Earth is set for a dramatic finale ...
# 2  Mars Rovers Relay Images Through Mars Express European Space Agency -- ESAs Mars Express has relayed pictures from one of NASA's Mars rovers for t...
#
#        dist
# 0  1.055337
# 1  1.120027
# 2  1.120295

# %% [markdown]
# ## 8. Vector Aggregations
#
# Calculate semantic centroids for entire categories directly in SQL.

# %%
agg_df = session.sql("""
    SELECT category, 
           vector_avg(embedding) AS centroid,
           COUNT(*) as count
    FROM news
    GROUP BY category
    order by count asc
""").to_pandas()
display(agg_df[["category", "count", "centroid"]])
# Out:
#    category  count  \
# 0  Business    106
# 1     World    122
# 2  Sci/Tech    127
# 3    Sports    145
#
#                                                                                                                                                 centroid
# 0  [-0.009712127, -0.019897964, 0.021966774, 0.01247101, 0.014252402, 0.000580147, -0.008388985, 0.0053979233, -0.0032875403, -0.00044038318, 0.00663...
# 1  [-4.8475005e-05, 0.020821085, 0.009778814, 0.004592271, 0.01837705, -0.0015207105, 0.014830185, -0.029480863, -0.0034735869, 0.026525691, 0.002212...
# 2  [-0.022988431, -0.0066769556, 0.017107781, -0.013084922, 0.018412977, -0.0053469883, 0.0069102254, 0.0046887686, -0.005161545, 0.010351745, 0.0123...
# 3  [-0.0013631884, 0.044090007, 0.0071727037, -0.016102785, 0.0072529507, 0.01989927, 0.04513628, 0.0041184663, 0.0029067388, 0.009585032, -0.0392480...

# %% [markdown]
# ## 9. Table Maintenance
#
# Keep the data lake healthy by compacting small files and vacuuming history.

# %%
print(f"Files before: {len(table.manifest().entries)}")
table.compact()
table.commit()
print(f"Files after: {len(table.manifest().entries)}")

table.vacuum(retention_versions=1)
print("Vacuum complete.")
# Out:
# Files before: 0
# Written data to /tmp/hyperstream_compact_d9f3f4ed-0c9d-419b-b94d-5d010a49b175/compacted_20260412135247_d9f3f4ed-0c9d-419b-b94d-5d010a49b175.parquet (500 rows)
# Files after: 0
# Vacuum complete.

# %% [markdown]
# ## 10. Advanced Partitioning
#
# Scale to massive datasets using identity partitioning on the category field.

# %%
PART_URI = "file:///tmp/part_demo"
if os.path.exists("/tmp/part_demo"): shutil.rmtree("/tmp/part_demo")

partition_spec = {
    "fields": [{"name": "category", "transform": "identity", "source_id": 2, "field_id": 1000}]
}

part_table = hdb.Table.create_partitioned(PART_URI, schema, partition_spec)
part_table.write(df[:100])
part_table.commit()

print("Partitioned physical layout:")
for entry in part_table.manifest().entries:
    print(f" - {entry.file_path.split('/')[-2:]}")
# Out:
# DEBUG: Rust Table created with runtime: true
# Optimizing data layout: Shuffling rows by vector similarity (LanceDB-style)...
# Written data to /tmp/part_demo/category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.parquet (12 rows)
# Written data to /tmp/part_demo/category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.parquet (30 rows)
# Written data to /tmp/part_demo/category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.parquet (37 rows)
# Written data to /tmp/part_demo/category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.parquet (21 rows)
# Building indexes for batch of 12 rows
# Indexing Int32 column: id
# Indexing String column: category
#   Found 1 unique values
# Building indexes for batch of 30 rows
# Building indexes for batch of 37 rows
# Indexing Int32 column: id
# String Inverted Index written to /tmp/part_demo/category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.category.inv.parquet
# Indexing Vector column: embedding (type=FixedSizeList(Field { data_type: Float32, nullable: true }, 384))
# Indexing String column: text
#   Found 12 unique values
# String Inverted Index written to /tmp/part_demo/category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.text.inv.parquet
# Building indexes for batch of 21 rows
# Indexing String column: text
# Indexing Vector column: embedding (type=FixedSizeList(Field { data_type: Float32, nullable: true }, 384))
#   Found 30 unique values
# String Inverted Index written to /tmp/part_demo/category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.text.inv.parquet
# Indexing String column: category
#   Found 1 unique values
# String Inverted Index written to /tmp/part_demo/category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.category.inv.parquet
# Indexing Int32 column: id
# Indexing String column: category
# Indexing String column: text
#   Found 1 unique values
# Indexing Vector column: embedding (type=FixedSizeList(Field { data_type: Float32, nullable: true }, 384))
#   Found 37 unique values
# Building HNSW-IVF index (blocking): 37 vectors, 384 dims, use_pq=false
# String Inverted Index written to /tmp/part_demo/category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.category.inv.parquet
# String Inverted Index written to /tmp/part_demo/category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.text.inv.parquet
# Indexing String column: category
# Indexing Vector column: embedding (type=FixedSizeList(Field { data_type: Float32, nullable: true }, 384))
#   Found 1 unique values
# Building HNSW-IVF index (blocking): 21 vectors, 384 dims, use_pq=false
# Indexing Int32 column: id
# Indexing String column: text
#   Found 21 unique values
# String Inverted Index written to /tmp/part_demo/category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.category.inv.parquet
# String Inverted Index written to /tmp/part_demo/category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.text.inv.parquet
# Building HNSW-IVF index (blocking): 30 vectors, 384 dims, use_pq=false
#   [K-Means] Converged early at iteration 2
#   [K-Means] Converged early at iteration 2
#   [K-Means] Converged early at iteration 2
# Building HNSW-IVF index (blocking): 12 vectors, 384 dims, use_pq=false
#   [K-Means] Converged early at iteration 2
# Partitioned physical layout:
# DEBUG: to_manifest_entry: segment_id=seg_34b2896c-1f91-445e-ab19-4b4dabd0378b, generated index_files=[IndexFile { file_path: "seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.embedding.cluster_1.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.parquet, found index_files=[IndexFile { file_path: "category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.embedding.cluster_1.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# Successfully attached 4 indexes to manifest for segment category=Sports/seg_34b2896c-1f91-445e-ab19-4b4dabd0378b.parquet
# DEBUG: to_manifest_entry: segment_id=seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601, generated index_files=[IndexFile { file_path: "seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.embedding.cluster_2.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.parquet, found index_files=[IndexFile { file_path: "category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.embedding.cluster_2.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# Successfully attached 4 indexes to manifest for segment category=Sci/Tech/seg_19fa8bd7-cf0a-4b17-b112-41a362ff1601.parquet
# DEBUG: to_manifest_entry: segment_id=seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0, generated index_files=[IndexFile { file_path: "seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.parquet, found index_files=[IndexFile { file_path: "category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf, generated index_files=[IndexFile { file_path: "seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.embedding.cluster_1.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.parquet, found index_files=[IndexFile { file_path: "category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.id.inv.parquet", index_type: "inverted", column_name: Some("id"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.text.inv.parquet", index_type: "inverted", column_name: Some("text"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.category.inv.parquet", index_type: "inverted", column_name: Some("category"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.embedding.cluster_1.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# Successfully attached 4 indexes to manifest for segment category=World/seg_f65a4cc0-c4c8-419a-ad79-7f8a26442aaf.parquet
# Successfully attached 4 indexes to manifest for segment category=Business/seg_1091104e-c3f3-4c82-b4ab-ccf1cd0699a0.parquet

# %% [markdown]
# ## 11. End-to-End RAG Pipeline
#
# Using SQuAD validation data to build a knowledge-backed Q&A system.

# %%
print("Loading SQuAD contexts...")
squad = load_dataset("squad", split="validation[0:100]")
squad_df = pd.DataFrame(squad).drop_duplicates(subset=["context"])

squad_emb = model.encode(squad_df["context"].tolist(), show_progress_bar=True)
squad_df["embedding"] = [list(e) for e in squad_emb]

rag_table = hdb.Table("rag_db_presentation")
rag_table.add_index_columns(["embedding", "context"])
rag_table.write(squad_df[["context", "title", "embedding"]])
rag_table.commit()
print("RAG knowledge base initialized.")
# Out:
# Loading SQuAD contexts...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Written data to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_3059324d-1edf-4004-b55a-56d5fd83d72d.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing String column: context
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true, metadata: {"iceberg.id": "301"} }))
# Indexing Int64 column: __index_level_0__
#   Found 4 unique values
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_3059324d-1edf-4004-b55a-56d5fd83d72d.context.inv.parquet
# Indexing String column: title
#   Found 1 unique values
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_3059324d-1edf-4004-b55a-56d5fd83d72d.title.inv.parquet
#   [K-Means] Converged early at iteration 2
# Written data to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true, metadata: {"iceberg.id": "301"} }))
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
# Indexing Int64 column: __index_level_0__
#   [K-Means] Converged early at iteration 2
# Indexing String column: title
#   Found 1 unique values
# Indexing String column: context
#   Found 4 unique values
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa.context.inv.parquet
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa.title.inv.parquet
# Written data to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_d2924121-9ff7-41b4-8c44-3eca405dc803.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing String column: context
#   Found 4 unique values
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_d2924121-9ff7-41b4-8c44-3eca405dc803.context.inv.parquet
# Indexing String column: title
#   Found 1 unique values
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_d2924121-9ff7-41b4-8c44-3eca405dc803.title.inv.parquet
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true, metadata: {"iceberg.id": "301"} }))
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
#   [K-Means] Converged early at iteration 2
# Indexing Int64 column: __index_level_0__
# Written data to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_1b943282-93e5-445d-8a80-1ab2e9d64294.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing String column: context
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true }))
#   Found 4 unique values
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
# Indexing String column: title
#   Found 1 unique values
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_1b943282-93e5-445d-8a80-1ab2e9d64294.context.inv.parquet
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_1b943282-93e5-445d-8a80-1ab2e9d64294.title.inv.parquet
# Indexing Int64 column: __index_level_0__
#   [K-Means] Converged early at iteration 2
# Written data to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.parquet (4 rows)
# Building indexes for batch of 4 rows
# Indexing String column: context
# Indexing Vector column: embedding (type=List(Field { data_type: Float32, nullable: true, metadata: {"iceberg.id": "301"} }))
#   Found 4 unique values
# Building HNSW-IVF index (blocking): 4 vectors, 384 dims, use_pq=false
# Indexing String column: title
#   Found 1 unique values
# Indexing Int64 column: __index_level_0__
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.context.inv.parquet
#   [K-Means] Converged early at iteration 2
# String Inverted Index written to /home/ralbright/projects/hyperstreamdb/demo/rag_db_presentation/seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.title.inv.parquet
# RAG knowledge base initialized.
# DEBUG: to_manifest_entry: segment_id=seg_3059324d-1edf-4004-b55a-56d5fd83d72d, generated index_files=[IndexFile { file_path: "seg_3059324d-1edf-4004-b55a-56d5fd83d72d.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3059324d-1edf-4004-b55a-56d5fd83d72d.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3059324d-1edf-4004-b55a-56d5fd83d72d.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_3059324d-1edf-4004-b55a-56d5fd83d72d.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa, generated index_files=[IndexFile { file_path: "seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_05257f66-5edd-47be-b1d6-6dc8ffb1c1fa.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_d2924121-9ff7-41b4-8c44-3eca405dc803, generated index_files=[IndexFile { file_path: "seg_d2924121-9ff7-41b4-8c44-3eca405dc803.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2924121-9ff7-41b4-8c44-3eca405dc803.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2924121-9ff7-41b4-8c44-3eca405dc803.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_d2924121-9ff7-41b4-8c44-3eca405dc803.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_1b943282-93e5-445d-8a80-1ab2e9d64294, generated index_files=[IndexFile { file_path: "seg_1b943282-93e5-445d-8a80-1ab2e9d64294.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1b943282-93e5-445d-8a80-1ab2e9d64294.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1b943282-93e5-445d-8a80-1ab2e9d64294.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_1b943282-93e5-445d-8a80-1ab2e9d64294.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: to_manifest_entry: segment_id=seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce, generated index_files=[IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# DEBUG: Background indexing task: segment=seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.parquet, found index_files=[IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.context.inv.parquet", index_type: "inverted", column_name: Some("context"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.__index_level_0__.inv.parquet", index_type: "inverted", column_name: Some("__index_level_0__"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.title.inv.parquet", index_type: "inverted", column_name: Some("title"), blob_type: None, offset: None, length: None }, IndexFile { file_path: "seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.embedding.cluster_0.hnsw.graph", index_type: "vector", column_name: Some("embedding"), blob_type: None, offset: None, length: None }]
# Successfully attached 4 indexes to manifest for segment seg_a98f0954-0fdb-4b5f-a69e-3797b339cdce.parquet

# %% [markdown]
# ## 12. Inference with Retrieval
#
# Connect retrieval to the LLM (requires GROQ_API_KEY).

# %%
def ask_hdb(question):
    # Convert question to an embedding (using your local model)
    q_emb = model.encode(question)
    
    # Perform a vector search on your table
    # This is where your table data gets pulled in!
    ctx_df = rag_table.to_pandas(vector_filter={
        "column": "embedding", 
        "query": q_emb, 
        "k": 3  # Get top 3 matching contexts
    })
    
    # Combine retrieved contexts into one string
    contexts = ctx_df["context"].tolist()
    prompt = f"Answer the question based ONLY on this context:\n\n" + "\n".join(contexts) + f"\n\nQuestion: {question}"
    
    # Use a supported Groq model
    model_name = "llama-3.3-70b-versatile"
    
    api_key = os.environ.get("GROQ_TOKEN")
    r = requests.post("https://api.groq.com/openai/v1/chat/completions", 
                      headers={"Authorization": f"Bearer {api_key}"},
                      json={"model": model_name, "messages": [{"role": "user", "content": prompt}]})
    
    res = r.json()
    if "choices" not in res:
        # This will show you the exact error from Groq (e.g., "model_not_found")
        print(f"Groq API Error: {res}")
        return "Error from API"
        
    return res["choices"][0]["message"]["content"]

# %%
question = "Where were the first modern Olympic games?"
print(f"Q: {question}\nA: {ask_hdb(question)}")
# Out:
# Q: Where were the first modern Olympic games?
# A: There is no information provided in the given context about the first modern Olympic Games. The context only talks about Super Bowl 50, its broadcast, commercial prices, and halftime show.

# %%
question = "What city was superbowl 50 played at?"
print(f"Q: {question}\nA: {ask_hdb(question)}")
# Out:
# Q: What city was superbowl 50 played at?
# A: The game was played at Santa Clara, California, in the San Francisco Bay Area, at Levi's Stadium.
